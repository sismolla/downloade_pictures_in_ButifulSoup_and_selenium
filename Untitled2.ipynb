# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.edge.options import Options

# %%
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14128\808063213.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(path)
# ...

# %%
def image_downloader():
    for i in range(7,10):
        path = "C:\\Users\\HP\\Desktop\\malicious\\edgedriver_win64\\msedgedriver.exe"
        URL = 'https://www.shutterstock.com/search/beast?page='+str(i)



        driver = webdriver.Edge(path)
        browser = driver.get(URL)
        page = driver.page_source
        
        

        soup = BeautifulSoup(page,'html.parser')

        div = soup.find('div', class_='mui-1nl4cpc-gridContainer-root')
        images = div.findAll('img')

        resolve_urls = []
        for imgs in images:
            pictures = imgs['src']
            resolve_urls.append(pictures)

        for url in resolve_urls:
            imgs = requests.get(url)
            open('images/'+ url.split('/')[-1],'wb').write(imgs.content)

image_downloader()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14128\2019149064.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(path)
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ...
